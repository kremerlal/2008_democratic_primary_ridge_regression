# %% [markdown]
# ## Obama-Clinton 2008 Democratic Primaries

# %% [markdown]
# Import everything

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib as mpl
import seaborn as sns
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import train_test_split, GridSearchCV
import statsmodels.formula.api as smf

from patsy import dmatrices, dmatrix, build_design_matrices

import math

# %%
# This makes it so that the pandas dataframes don't get truncated horizontally.
pd.options.display.max_columns = 200

# %% [markdown]
# Bring in the data

# %%
elect_df = pd.read_csv("Obama.csv")

# %% [markdown]
# Split training & test

# %%
elect_df["ElectionDate"] = pd.to_datetime(elect_df["ElectionDate"])

# %% [markdown]
# All of the data before February 19, 2008 is our training set and all of the data after that point is our testing set.

# %%
elect_df_train = elect_df[elect_df["ElectionDate"] < pd.to_datetime("2/19/2008")].copy()

# %%
elect_df_test = elect_df[elect_df["ElectionDate"] >= pd.to_datetime("2/19/2008")].copy()

# %% [markdown]
# Create more variables

# %%
elect_df_train["Obama_margin"] = elect_df_train["Obama"] - elect_df_train["Clinton"]
elect_df_train["Obama_margin_percent"] = elect_df_train["Obama_margin"] / elect_df_train["TotalVote"]
elect_df_train["Obama_wins"] = elect_df_train["Obama_margin"] > 0

# %%
def summarize_dataframe(df):
    """Summarize a dataframe, and report missing values."""
    missing_values = pd.DataFrame({'Variable Name': df.columns,
                                   'Data Type': df.dtypes,
                                   'Missing Values': df.isnull().sum(),
                                   'Unique Values': [df[name].nunique() for name in df.columns]}
                                 ).set_index('Variable Name')
    with pd.option_context("display.max_rows", 1000):
        display(pd.concat([missing_values, df.describe(include='all').transpose()], axis=1).fillna(""))

# %%
summarize_dataframe(elect_df)
# Out:
# /var/folders/x9/19r3j4q963qdgn68y0lk16d00000gn/T/ipykernel_32037/2697573813.py:9: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   display(pd.concat([missing_values, df.describe(include='all').transpose()], axis=1).fillna(""))
#                            Data Type  Missing Values  Unique Values   count  \
# County                        object               0           1691  2868.0
# State                         object               0             46  2868.0
# Region                        object               0              4  2868.0
# FIPS                           int64               0           2868  2868.0
# ElectionDate          datetime64[ns]               0             18  2868.0
# ElectionType                  object               0              2  2868.0
# TotalVote                    float64            1131           1490  1737.0
# Clinton                      float64            1131           1338  1737.0
# Obama                        float64            1131           1314  1737.0
# MalesPer100Females           float64               0            391  2868.0
# AgeBelow35                   float64               0            310  2868.0
# Age35to65                    float64               0            215  2868.0
# Age65andAbove                float64               0            227  2868.0
# White                        float64               0            547  2868.0
# Black                        float64              80            489  2788.0
# Asian                        float64              94            104  2774.0
# AmericanIndian               float64              99            158  2769.0
# Hawaiian                     float64               0             20  2868.0
# Hispanic                     float64               0            387  2868.0
# HighSchool                   float64               1            410  2867.0
# Bachelors                    float64               1            369  2867.0
# Poverty                      float64               1            277  2867.0
# IncomeAbove75K               float64               2            357  2866.0
# MedianIncome                 float64               1           2740  2867.0
# AverageIncome                float64              30           2624  2838.0
# UnemployRate                 float64               1            103  2867.0
# ManfEmploy                   float64             293           2574  2575.0
# SpeakingNonEnglish           float64               1            390  2867.0
# Medicare                     float64               1           2584  2867.0
# MedicareRate                 float64               1           2629  2867.0
# SocialSecurity               float64               1           2020  2867.0
# SocialSecurityRate           float64               1           2653  2867.0
# RetiredWorkers               float64               1           1702  2867.0
# Disabilities                 float64               8           1748  2860.0
# DisabilitiesRate             float64               8           2171  2860.0
# Homeowner                    float64               2            374  2866.0
# SameHouse1995and2000         float64               1            374  2867.0
# Pop                            int64               0           2827  2868.0
# PopDensity                   float64               0           1548  2868.0
# LandArea                     float64               1           1362  2867.0
# FarmArea                     float64              87            795  2781.0
#
#                      unique                  top  freq      first       last  \
# County                 1691           Washington    30        NaT        NaT
# State                    46                   TX   251        NaT        NaT
# Region                    4                South  1419        NaT        NaT
# FIPS                                                          NaT        NaT
# ElectionDate             18  2008-02-05 00:00:00  1128 2008-01-03 2008-06-03
# ElectionType              2              Primary  2558        NaT        NaT
# TotalVote                                                     NaT        NaT
# Clinton                                                       NaT        NaT
# Obama                                                         NaT        NaT
# MalesPer100Females                                            NaT        NaT
# AgeBelow35                                                    NaT        NaT
# Age35to65                                                     NaT        NaT
# Age65andAbove                                                 NaT        NaT
# White                                                         NaT        NaT
# Black                                                         NaT        NaT
# Asian                                                         NaT        NaT
# AmericanIndian                                                NaT        NaT
# Hawaiian                                                      NaT        NaT
# Hispanic                                                      NaT        NaT
# HighSchool                                                    NaT        NaT
# Bachelors                                                     NaT        NaT
# Poverty                                                       NaT        NaT
# IncomeAbove75K                                                NaT        NaT
# MedianIncome                                                  NaT        NaT
# AverageIncome                                                 NaT        NaT
# UnemployRate                                                  NaT        NaT
# ManfEmploy                                                    NaT        NaT
# SpeakingNonEnglish                                            NaT        NaT
# Medicare                                                      NaT        NaT
# MedicareRate                                                  NaT        NaT
# SocialSecurity                                                NaT        NaT
# SocialSecurityRate                                            NaT        NaT
# RetiredWorkers                                                NaT        NaT
# Disabilities                                                  NaT        NaT
# DisabilitiesRate                                              NaT        NaT
# Homeowner                                                     NaT        NaT
# SameHouse1995and2000                                          NaT        NaT
# Pop                                                           NaT        NaT
# PopDensity                                                    NaT        NaT
# LandArea                                                      NaT        NaT
# FarmArea                                                      NaT        NaT
#
#                               mean            std       min       25%  \
# County
# State
# Region
# FIPS                  31029.039052   15411.398662    1001.0   18102.5
# ElectionDate
# ElectionType
# TotalVote               12863.7962   53071.884245      13.0     732.0
# Clinton                5973.738054   25402.029497       4.0     329.0
# Obama                  6178.122625   27477.231157       4.0     254.0
# MalesPer100Females       99.081729       9.276792      76.2      94.9
# AgeBelow35               45.657252       5.539505       4.5      42.2
# Age35to65                39.587448       3.414974      18.6      38.0
# Age65andAbove            14.757671       3.879482       2.2      12.2
# White                    86.762134      15.965025       6.7      81.9
# Black                     9.900215      15.098619       0.1       0.6
# Asian                      1.06496       2.285771       0.1       0.3
# AmericanIndian             1.68931       6.418587       0.1       0.2
# Hawaiian                  0.077057       0.667552       0.0       0.0
# Hispanic                  7.349442      12.874248       0.1       1.2
# HighSchool               76.898151       8.852567      34.7      70.6
# Bachelors                16.453784       7.921446       4.9      11.1
# Poverty                  13.945553        5.24943       2.6      10.1
# IncomeAbove75K           14.023447       7.559124       1.5       9.2
# MedianIncome          39107.335542   10262.621095   16868.0   32314.0
# AverageIncome         27280.887949    6731.846182    5148.0   23250.0
# UnemployRate              4.899198       1.625128       1.5       3.8
# ManfEmploy               10.656417        7.73343  0.202429  4.719391
# SpeakingNonEnglish        8.617021      11.273343       0.4       3.0
# Medicare              13724.160098   37807.170641       7.0    2162.5
# MedicareRate          17088.155215     4947.33554      60.0   14108.5
# SocialSecurity        15616.140565   40316.047789      20.0    2547.5
# SocialSecurityRate    19938.812347    4756.541802    1518.0   16827.0
# RetiredWorkers         9868.735612   26369.776166      15.0    1490.0
# Disabilities           2381.356993   10565.058494       4.0    274.75
# DisabilitiesRate       2693.441958    1904.872546     125.0   1380.25
# Homeowner                 73.88866       7.576884      19.6      70.5
# SameHouse1995and2000     58.742379       7.423108      15.4      54.3
# Pop                   99225.983264  319260.353417      60.0  12334.75
# PopDensity              265.177755    1787.612548       0.1      19.8
# LandArea               1003.504011    1371.588433       2.0     434.0
# FarmArea                293.651564      375.84185       1.0      84.0
#
#                            50%        75%        max
# County
# State
# Region
# FIPS                   30110.0    46123.5    56045.0
# ElectionDate
# ElectionType
# TotalVote               2330.0     6418.0  1413869.0
# Clinton                 1106.0     3200.0   771700.0
# Obama                    878.0     2749.0   743686.0
# MalesPer100Females        97.6      100.5      200.9
# AgeBelow35                45.4       48.7       75.8
# Age35to65                 39.8       41.4       79.2
# Age65andAbove             14.4       17.0       33.7
# White                     93.7       97.5      100.0
# Black                      2.6     11.925       86.0
# Asian                      0.5        0.9       46.6
# AmericanIndian             0.4        0.8       91.8
# Hawaiian                   0.0        0.1       30.6
# Hispanic                   2.4        6.8       97.6
# HighSchool                78.7       83.6       97.0
# Bachelors                 14.3       19.3       63.7
# Poverty                   13.2       16.9       39.4
# IncomeAbove75K            11.9       16.4       57.3
# MedianIncome           37272.0    43430.5    98245.0
# AverageIncome          26222.0   29840.25    93377.0
# UnemployRate               4.7        5.7       15.3
# ManfEmploy            8.950863  14.961274  57.229045
# SpeakingNonEnglish         4.6        8.6       92.1
# Medicare                4514.0    10613.0  1059297.0
# MedicareRate           16863.0    19853.5    60845.0
# SocialSecurity          5360.0    12845.0  1047590.0
# SocialSecurityRate     20040.0    23032.0    41943.0
# RetiredWorkers          3095.0     7722.5   681035.0
# Disabilities             698.5    1671.25   400125.0
# DisabilitiesRate        2192.5     3436.0    20185.0
# Homeowner                 75.2       78.9       89.6
# SameHouse1995and2000      59.4       64.0       90.5
# Pop                    26967.5    68372.5  9948081.0
# PopDensity               47.25    118.025    70190.8
# LandArea                 626.0      950.0    20105.0
# FarmArea                 182.0      348.0     4595.0

# %% [markdown]
# Split into smaller sets & validation

# %%
elect_df_smaller_train, elect_df_validation = train_test_split(elect_df_train, test_size=.25, random_state=201)

# %%
elect_df_smaller_train
# Out:
#             County State     Region   FIPS ElectionDate ElectionType  \
# 1677  Rappahannock    VA      South  51157   2008-02-12      Primary
# 594         Greene    GA      South  13133   2008-02-05      Primary
# 642           Pike    GA      South  13231   2008-02-05      Primary
# 1200      Johnston    OK      South  40069   2008-02-05      Primary
# 81           Scott    IA    Midwest  19163   2008-01-03     Caucuses
# ...            ...   ...        ...    ...          ...          ...
# 868        Douglas    MN    Midwest  27041   2008-02-05     Caucuses
# 1377      Caldwell    LA      South  22021   2008-02-09      Primary
# 1536         Grant    WA       West  53025   2008-02-09      Primary
# 1577    Washington    ME  Northeast  23029   2008-02-10     Caucuses
# 512       Sedgwick    CO       West   8115   2008-02-05     Caucuses
#
#       TotalVote  Clinton   Obama  MalesPer100Females  AgeBelow35  Age35to65  \
# 1677     1300.0    515.0   774.0                97.7        38.4       46.3
# 594      1822.0    518.0  1245.0                94.7        46.4       37.5
# 642      1322.0    639.0   612.0               102.1        50.0       39.3
# 1200     2014.0   1181.0   403.0                96.3        45.0       39.0
# 81        350.0    103.0   169.0                96.6        46.5       41.4
# ...         ...      ...     ...                 ...         ...        ...
# 868       771.0    362.0   399.0                99.3        44.0       37.8
# 1377      897.0    441.0   313.0               103.8        47.5       38.3
# 1536     5003.0   2615.0  2186.0               105.2        54.2       34.4
# 1577       55.0     20.0    35.0                95.6        39.6       42.7
# 512        21.0     14.0     7.0                99.0        39.3       37.6
#
#       Age65andAbove  White  Black  Asian  AmericanIndian  Hawaiian  Hispanic  \
# 1677           15.1   93.4    5.4    0.2             0.2       0.0       1.9
# 594            16.1   58.8   40.3    0.4             0.3       0.1       3.5
# 642            10.8   86.5   12.5    0.5             0.2       0.0       1.4
# 1200           15.9   77.7    2.0    0.3            15.5       0.0       3.1
# 81             12.1   89.9    6.2    1.8             0.3       0.0       4.5
# ...             ...    ...    ...    ...             ...       ...       ...
# 868            18.3   98.5    0.4    0.4             0.3       0.0       0.9
# 1377           14.2   81.6   17.7    0.2             0.4       0.0       1.6
# 1536           11.5   95.1    1.1    1.1             1.4       0.1      33.8
# 1577           17.8   93.8    0.4    0.4             4.6       0.0       1.1
# 512            23.0   98.0    0.6    0.9             NaN       0.2      13.7
#
#       HighSchool  Bachelors  Poverty  IncomeAbove75K  MedianIncome  \
# 1677        76.0       22.9      6.6            25.6       52195.0
# 594         70.1       17.6     18.2            18.8       36104.0
# 642         75.3       14.0     10.5            18.5       47796.0
# 1200        69.1       13.3     16.1             7.5       28405.0
# 81          86.3       24.9     12.3            20.5       48884.0
# ...          ...        ...      ...             ...           ...
# 868         85.6       17.3      7.5            13.6       42640.0
# 1377        65.4        8.8     20.6             8.1       31957.0
# 1536        72.2       13.7     16.2            13.1       38627.0
# 1577        79.9       14.7     17.4             7.8       29721.0
# 512         79.3       13.4     11.3             7.6       29871.0
#
#       AverageIncome  UnemployRate  ManfEmploy  SpeakingNonEnglish  Medicare  \
# 1677        33902.0           2.3    3.252033                 3.0    1552.0
# 594         27818.0           5.9    6.946108                 3.6    2938.0
# 642         25669.0           4.6   10.652572                 2.9    2206.0
# 1200        21715.0           4.3   14.529221                 3.4    2029.0
# 81          35018.0           3.8   11.743811                 5.6   22900.0
# ...             ...           ...         ...                 ...       ...
# 868         30121.0           3.8   11.195793                 3.2    7237.0
# 1377        21050.0           3.8    2.721088                 3.3    1864.0
# 1536        22538.0           6.6    9.194838                28.3   11063.0
# 1577        25094.0           7.4    8.664908                 5.4    7501.0
# 512         27641.0           3.2         NaN                 9.3     642.0
#
#       MedicareRate  SocialSecurity  SocialSecurityRate  RetiredWorkers  \
# 1677       21345.0          1485.0             20424.0          1035.0
# 594        18722.0          3655.0             23291.0          2335.0
# 642        13678.0          2680.0             16617.0          1715.0
# 1200       19778.0          2505.0             24418.0          1380.0
# 81         14224.0         26525.0             16475.0         17260.0
# ...            ...             ...                 ...             ...
# 868        20596.0          8265.0             23522.0          5690.0
# 1377       17647.0          2040.0             19313.0          1025.0
# 1536       13620.0         12605.0             15518.0          8115.0
# 1577       22426.0          8570.0             25622.0          5270.0
# 512        25386.0           685.0             27086.0           475.0
#
#       Disabilities  DisabilitiesRate  Homeowner  SameHouse1995and2000     Pop  \
# 1677          95.0            1307.0       75.2                  66.1    7203
# 594          535.0            3409.0       76.4                  56.4   15534
# 642          279.0            1730.0       81.6                  57.4   16801
# 1200         439.0            4279.0       73.9                  56.5   10436
# 81          3083.0            1915.0       70.6                  54.0  162621
# ...            ...               ...        ...                   ...     ...
# 868          469.0            1335.0       77.2                  60.7   35467
# 1377         470.0            4449.0       79.2                  60.5   10615
# 1536        1735.0            2136.0       66.7                  50.0   82612
# 1577        1270.0            3797.0       77.7                  66.7   33288
# 512           43.0            1700.0       73.0                  64.1    2467
#
#       PopDensity  LandArea  FarmArea  Obama_margin  Obama_margin_percent  \
# 1677        27.0     267.0      78.0         259.0              0.199231
# 594         40.0     406.0      52.0         727.0              0.399012
# 642         76.9     219.0      44.0         -27.0             -0.020424
# 1200        16.2     658.0     326.0        -778.0             -0.386296
# 81         355.1     468.0     229.0          66.0              0.188571
# ...          ...       ...       ...           ...                   ...
# 868         55.9     720.0     273.0          37.0              0.047990
# 1377        20.1     541.0      61.0        -128.0             -0.142698
# 1536        30.8    2791.0    1074.0        -429.0             -0.085749
# 1577        13.0    3255.0     152.0          15.0              0.272727
# 512          4.5     550.0     274.0          -7.0             -0.333333
#
#       Obama_wins
# 1677        True
# 594         True
# 642        False
# 1200       False
# 81          True
# ...          ...
# 868         True
# 1377       False
# 1536       False
# 1577        True
# 512        False
#
# [1302 rows x 44 columns]

# %% [markdown]
# Impute missing data

# %%
imputer_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer_zero = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value=0)

# %%
continuous_mean = ['MalesPer100Females',
                   'AgeBelow35', 'Age35to65','Age65andAbove']

continuous_zero = ['White', 
                   'Black',
                   'Asian',
                   'AmericanIndian',
                   'Hawaiian',
                  'Hispanic']

# %% [markdown]
# In order to impute anything, we need to `fit` the imputer. The imputer needs to know what the mean of all of the existing data is, so we give it the data set, and we let it learn the mean. After it has been fitted, we can use it to actually transform the data.

# %%
imputer_mean.fit(elect_df_train[continuous_mean])
imputer_mean.fit(elect_df_smaller_train[continuous_mean])
elect_df_train[continuous_mean] = imputer_mean.transform(elect_df_train[continuous_mean])
elect_df_smaller_train[continuous_mean] = imputer_mean.transform(elect_df_smaller_train[continuous_mean])
elect_df_validation[continuous_mean] = imputer_mean.transform(elect_df_validation[continuous_mean])
# Out:
# /Users/locolaurel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /Users/locolaurel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)

# %%
imputer_zero.fit(elect_df_train[continuous_zero])
imputer_zero.fit(elect_df_smaller_train[continuous_zero])
elect_df_train[continuous_zero] = imputer_zero.transform(elect_df_train[continuous_zero])
elect_df_smaller_train[continuous_zero] = imputer_zero.transform(elect_df_smaller_train[continuous_zero])
elect_df_validation[continuous_zero] = imputer_zero.transform(elect_df_validation[continuous_zero])
# Out:
# /Users/locolaurel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /Users/locolaurel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)

# %%
imputer_mean.fit(elect_df_train.loc[:, "HighSchool":"FarmArea"])
imputer_mean.fit(elect_df_smaller_train.loc[:, "HighSchool":"FarmArea"])
elect_df_train.loc[:, "HighSchool":"FarmArea"] = imputer_mean.transform(elect_df_train.loc[:, "HighSchool":"FarmArea"])
elect_df_smaller_train.loc[:, "HighSchool":"FarmArea"] = imputer_mean.transform(elect_df_smaller_train.loc[:, "HighSchool":"FarmArea"])
elect_df_validation.loc[:, "HighSchool":"FarmArea"] = imputer_mean.transform(elect_df_validation.loc[:, "HighSchool":"FarmArea"])
# Out:
# /Users/locolaurel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# /Users/locolaurel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)

# %% [markdown]
# Accuracy function

# %%
def accuracy(y_true, y_pred):
    """Function that returns a table showing RMSE and MAE."""
    acc_df = pd.DataFrame(data = {"RMSE": [mean_squared_error(y_true, y_pred)**(1/2)],
                                  "MAE": [mean_absolute_error(y_true, y_pred)],
                                  "R^2": [r2_score(y_true, y_pred)]})
    display(acc_df.style.hide_index())

# %% [markdown]
# Training model:

# %%
variables2 = [variable for variable in elect_df_smaller_train.columns if variable not in ['FIPS', 'County', 'State', 'ElectionDate', 'TotalVote', 'Obama_margin', 'Obama_margin_percent', 'Obama_wins', 'Clinton', 'Obama','Region','ElectionType']]

# %%
formula2 = 'Obama_margin_percent ~ ElectionType' +  ' + Region*' + "(standardize(" + ") + standardize(".join(variables2[1:]) + "))"

# %%
formula2
# Out:
# 'Obama_margin_percent ~ ElectionType + Region*(standardize(AgeBelow35) + standardize(Age35to65) + standardize(Age65andAbove) + standardize(White) + standardize(Black) + standardize(Asian) + standardize(AmericanIndian) + standardize(Hawaiian) + standardize(Hispanic) + standardize(HighSchool) + standardize(Bachelors) + standardize(Poverty) + standardize(IncomeAbove75K) + standardize(MedianIncome) + standardize(AverageIncome) + standardize(UnemployRate) + standardize(ManfEmploy) + standardize(SpeakingNonEnglish) + standardize(Medicare) + standardize(MedicareRate) + standardize(SocialSecurity) + standardize(SocialSecurityRate) + standardize(RetiredWorkers) + standardize(Disabilities) + standardize(DisabilitiesRate) + standardize(Homeowner) + standardize(SameHouse1995and2000) + standardize(Pop) + standardize(PopDensity) + standardize(LandArea) + standardize(FarmArea))'

# %%
y_linear2, X_linear2 = dmatrices(formula2, elect_df_smaller_train, return_type="dataframe")

# %%
X_validation_linear2 = build_design_matrices([X_linear2.design_info], elect_df_validation, return_type="dataframe")[0]

# %%
alphas = np.logspace(-5,5,30)

# %% [markdown]
# You might get a few warnings below. Ignore them.

# %%
# %%time
coefs = []
for a in alphas:
    lm_ridge = Ridge(alpha=a, fit_intercept=False, max_iter=1000000)
    lm_ridge.fit(X_linear2, y_linear2)
    coefs.append(lm_ridge.coef_[0])
# Out:
# CPU times: user 343 ms, sys: 11.5 ms, total: 355 ms
# Wall time: 229 ms

# %%
gs_ridge2 = GridSearchCV(Ridge(fit_intercept=False, max_iter=1000000), {"alpha": alphas}, scoring='neg_mean_squared_error', cv=5)

# %%
# %%time
gs_ridge2.fit(X_linear2, y_linear2)
# Out:
# CPU times: user 2.55 s, sys: 25.9 ms, total: 2.57 s
# Wall time: 1.37 s
# GridSearchCV(cv=5, estimator=Ridge(fit_intercept=False, max_iter=1000000),
#              param_grid={'alpha': array([1.00000000e-05, 2.21221629e-05, 4.89390092e-05, 1.08263673e-04,
#        2.39502662e-04, 5.29831691e-04, 1.17210230e-03, 2.59294380e-03,
#        5.73615251e-03, 1.26896100e-02, 2.80721620e-02, 6.21016942e-02,
#        1.37382380e-01, 3.03919538e-01, 6.72335754e-01, 1.48735211e+00,
#        3.29034456e+00, 7.27895384e+00, 1.61026203e+01, 3.56224789e+01,
#        7.88046282e+01, 1.74332882e+02, 3.85662042e+02, 8.53167852e+02,
#        1.88739182e+03, 4.17531894e+03, 9.23670857e+03, 2.04335972e+04,
#        4.52035366e+04, 1.00000000e+05])},
#              scoring='neg_mean_squared_error')

# %%
gs_ridge_pred2 = gs_ridge2.predict(X_validation_linear2)

# %%
accuracy(gs_ridge_pred2, elect_df_validation["Obama_margin_percent"])
# Out:
# <style type="text/css">
# </style>
# <table id="T_db337_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >RMSE</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >R^2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_db337_row0_col0" class="data row0 col0" >0.158079</td>
#       <td id="T_db337_row0_col1" class="data row0 col1" >0.115398</td>
#       <td id="T_db337_row0_col2" class="data row0 col2" >0.650562</td>
#     </tr>
#   </tbody>
# </table>

# %%
def get_linear_importances(model, data):
    # This section is to handle both LASSO and ridge.
    if len(model.coef_) == 1:
        coefficients = np.concatenate((model.coef_[0], [model.intercept_]))
    else:
        coefficients = np.concatenate((model.coef_, model.intercept_))
    coef_df = pd.DataFrame({'Importance': coefficients}, index=data.columns.append(pd.Index(["Model Intercept"])))
    return coef_df.reindex(coef_df.Importance.abs().sort_values(ascending=False).index)

# %%
get_linear_importances(gs_ridge2.best_estimator_, X_linear2)
# Out:
#                                                     Importance
# Region[T.South]                                      -0.185802
# Region[T.Northeast]:standardize(SameHouse1995an...   -0.139900
# Region[T.Northeast]                                  -0.108427
# standardize(Black)                                    0.107146
# Region[T.Northeast]:standardize(Age35to65)            0.105192
# ...                                                        ...
# standardize(PopDensity)                               0.001800
# Region[T.Northeast]:standardize(Bachelors)           -0.001563
# standardize(ManfEmploy)                               0.001040
# Region[T.South]:standardize(RetiredWorkers)           0.000269
# Model Intercept                                       0.000000
#
# [130 rows x 1 columns]

# %% [markdown]
# Model to submit:

# %%
variables = [variable for variable in elect_df_train.columns if variable not in ['FIPS', 'County', 'State', 'ElectionDate', 'TotalVote', 'Obama_margin', 'Obama_margin_percent', 'Obama_wins', 'Clinton', 'Obama','MalesPer100Females','Hawaiian','Region','ElectionType']]

# %%
formula = 'Obama_margin_percent ~ (Region*ElectionType)' +  ' + Region*' + "(standardize(" + ") + standardize(".join(variables[1:]) + "))"

# %%
formula
# Out:
# 'Obama_margin_percent ~ (Region*ElectionType) + Region*(standardize(Age35to65) + standardize(Age65andAbove) + standardize(White) + standardize(Black) + standardize(Asian) + standardize(AmericanIndian) + standardize(Hispanic) + standardize(HighSchool) + standardize(Bachelors) + standardize(Poverty) + standardize(IncomeAbove75K) + standardize(MedianIncome) + standardize(AverageIncome) + standardize(UnemployRate) + standardize(ManfEmploy) + standardize(SpeakingNonEnglish) + standardize(Medicare) + standardize(MedicareRate) + standardize(SocialSecurity) + standardize(SocialSecurityRate) + standardize(RetiredWorkers) + standardize(Disabilities) + standardize(DisabilitiesRate) + standardize(Homeowner) + standardize(SameHouse1995and2000) + standardize(Pop) + standardize(PopDensity) + standardize(LandArea) + standardize(FarmArea))'

# %%
y_linear, X_linear = dmatrices(formula, elect_df_train, return_type="dataframe")

# %%
X_validation_linear = build_design_matrices([X_linear.design_info], elect_df_test, return_type="dataframe")[0]

# %%
alphas = np.logspace(-5,10, 31)

# %% [markdown]
# You might get a few warnings below. Ignore them.

# %%
# %%time
coefs = []
for a in alphas:
    lm_ridge = Ridge(alpha=a, fit_intercept=False, max_iter=1000000)
    lm_ridge.fit(X_linear, y_linear)
    coefs.append(lm_ridge.coef_[0])
# Out:
# CPU times: user 315 ms, sys: 6.82 ms, total: 322 ms
# Wall time: 226 ms

# %%
gs_ridge = GridSearchCV(Ridge(fit_intercept=False, max_iter=1000000), {"alpha": alphas}, scoring='neg_mean_squared_error', cv=5)

# %%
# %%time
gs_ridge.fit(X_linear, y_linear)
# Out:
# CPU times: user 2.62 s, sys: 46.1 ms, total: 2.67 s
# Wall time: 1.44 s
# GridSearchCV(cv=5, estimator=Ridge(fit_intercept=False, max_iter=1000000),
#              param_grid={'alpha': array([1.00000000e-05, 3.16227766e-05, 1.00000000e-04, 3.16227766e-04,
#        1.00000000e-03, 3.16227766e-03, 1.00000000e-02, 3.16227766e-02,
#        1.00000000e-01, 3.16227766e-01, 1.00000000e+00, 3.16227766e+00,
#        1.00000000e+01, 3.16227766e+01, 1.00000000e+02, 3.16227766e+02,
#        1.00000000e+03, 3.16227766e+03, 1.00000000e+04, 3.16227766e+04,
#        1.00000000e+05, 3.16227766e+05, 1.00000000e+06, 3.16227766e+06,
#        1.00000000e+07, 3.16227766e+07, 1.00000000e+08, 3.16227766e+08,
#        1.00000000e+09, 3.16227766e+09, 1.00000000e+10])},
#              scoring='neg_mean_squared_error')

# %%
gs_ridge_pred = gs_ridge.predict(X_validation_linear)

# %%
def get_linear_importances(model, data):
    # This section is to handle both LASSO and ridge.
    if len(model.coef_) == 1:
        coefficients = np.concatenate((model.coef_[0], [model.intercept_]))
    else:
        coefficients = np.concatenate((model.coef_, model.intercept_))
    coef_df = pd.DataFrame({'Importance': coefficients}, index=data.columns.append(pd.Index(["Model Intercept"])))
    return coef_df.reindex(coef_df.Importance.abs().sort_values(ascending=False).index)

# %%
get_linear_importances(gs_ridge.best_estimator_, X_linear)
# Out:
#                                                     Importance
# Region[T.Northeast]:ElectionType[T.Primary]          -0.109740
# Region[T.South]:standardize(Black)                    0.096173
# standardize(Black)                                    0.086440
# Region[T.South]                                      -0.082756
# Region[T.South]:ElectionType[T.Primary]              -0.082756
# ...                                                        ...
# standardize(PopDensity)                               0.000671
# Region[T.Northeast]:standardize(Disabilities)        -0.000478
# Region[T.West]:standardize(Medicare)                  0.000228
# Region[T.Northeast]:standardize(SocialSecurityR...    0.000088
# Model Intercept                                       0.000000
#
# [125 rows x 1 columns]

# %%
bm_all_fit_pred = gs_ridge_pred

# %%
submission_df = pd.DataFrame(bm_all_fit_pred, index=elect_df_test.index, columns=['Obama_margin_percent'])

# %%
submission_df

# %%
submission_df.to_csv("ObamaSubmission.csv", index_label='Row')
